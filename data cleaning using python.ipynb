# %%
pip install pandas

# %%
import pandas as pd
# Out:
# C:\Users\vrajp\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\vrajp\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
data = pd.read_json("C:\\Users\\vrajp\\Downloads\\zfunds.in (3)\\zfunds.in.json",encoding="utf-16",lines=True)

# %%
data
# Out:
#                                          _id _index  _score  \
# 0       9f442d97-2d46-4ff1-9f7b-d90a3a524570  users     NaN
# 1       4cf8f42e-71db-4fa3-a302-c2bcb50b2487  users     NaN
# 2       bee8f955-e73a-4035-8293-d0e16d0b791d  users     NaN
# 3       4eb590c9-de32-4ea6-a92b-4c0781d902b6  users     NaN
# 4       597cadea-d63a-4828-b73c-da8dfff329f1  users     NaN
# ...                                      ...    ...     ...
# 134732  888d1e38-1dd9-48c4-9ea7-a2c4909d16c9  users     NaN
# 134733  552e522a-35eb-468d-989d-951f9036f823  users     NaN
# 134734  6a618271-ef85-4dae-93f3-affdf5d08b6d  users     NaN
# 134735  2d03d8a0-1cab-43d2-8b60-b1580cbdf885  users     NaN
# 134736  603ff4da-ddeb-45cd-836d-081b63a9ba34  users     NaN
#
#                                                   _source  _type      sort  \
# 0       {'about': 'NR Shreyas CrossingAmbawadiAhmedaba...  users       [0]
# 1       {'about': 'Kantilal ComplexMohoneKalyan421102M...  users       [1]
# ...

# %%
data["_source"][1]
# Out:
# {'about': 'Kantilal ComplexMohoneKalyan421102MAIndiaABAPP3781EABAPP3781EMaharashtrahemant.pandya62@gmail.com9920605610+91992060561044732YFinancial Planning, Mutual Funds, NISM certified',
#  'address': 'B/403 Bldg No.2 ,Kantilal Complex ,Mohone',
#  'arn': '65162',
#  'arn_valid_till': '20/06/2022',
#  'capabilities': [' Mutual Funds', ' NISM certified', 'Financial Planning'],
#  'city': 'Kalyan',
#  'createdAt': '2020-01-20T04:06:54.444Z',
#  'es_refresh': '2022-05-13T15:09:13.739Z',
#  'id': '4cf8f42e-71db-4fa3-a302-c2bcb50b2487',
#  'kyd_compliant': 'Y',
#  'name': 'Hemant Kantilal Pandya',
#  'products': ['Mutual Funds'],
#  'profile_status': 'incomplete',
#  'role': ['expert'],
#  'status': 'unclaimed',
#  'telephoneO': '9920605610'}

# %% [markdown]
# # data["_source"][1]

# %%
l=[]
for i in data["_source"]:
    if "about" in i.keys():
        l.append(i["about"])

# %%
len(l)
# Out:
# 113410

# %%
l[4]
# Out:
# "Biswajit Mondal is a AMFI registered distributor.  Biswajit Mondal's office is located at Vill-ShillaP.O-RamgopalpurDist- Purba BarddhamanBurdwan.  They are licensed to distribute mutual funds under PAN number AHJPM8429P and they are KYD (Know Your Distributor) Complaint.  All transactions to Biswajit Mondal are tagged in ARN-12388"

# %%
l[3]
# Out:
# "Asian Markets Securities Pvt. Ltd is a AMFI registered distributor.  Asian Markets Securities Pvt. Ltd's office is located at Athena House Row H No 2Rajini Gandha GokuldhamGoregaon EastMUMBAI.  They are licensed to distribute mutual funds under PAN number AAACA9493L and they are KYD (Know Your Distributor) Complaint.  All transactions to Asian Markets Securities Pvt. Ltd are tagged in ARN-0170"

# %%
l[5]
# Out:
# 'Mohammadwadi RoadHadapsarPune411028MAIndiaBUSPS8328EBUSPS8328EMaharashtrashaheen_shaikh88@yahoo.com+91956179536442761YFinancial Planning, Mutual Funds, NISM certified'

# %%
l[6]
# Out:
# "Alka Rajendra Khandelwal is a AMFI registered distributor.  Alka Rajendra Khandelwal's office is located at Dhar RoadManawarManawar.  They are licensed to distribute mutual funds under PAN number ADQPK3167M and they are KYD (Know Your Distributor) Complaint.  All transactions to Alka Rajendra Khandelwal are tagged in ARN-23225"

# %%
l[7]
# Out:
# 'DurgapurBurdwan713206WBIndiaACQPR6043JACQPR6043JWest Bengal42587YFinancial Planning, Mutual Funds, NISM certified'

# %%
for i in l[0:50]:
    print(i)
    print()
    print()
# Out:
# NR Shreyas CrossingAmbawadiAhmedabad380006GUINDIABDEPS4292NBDEPS4292NGujaratjapanshah22@gmail.com25466694+91989894929244854YFinancial Planning, Mutual Funds, NISM certified
#
#
# Kantilal ComplexMohoneKalyan421102MAIndiaABAPP3781EABAPP3781EMaharashtrahemant.pandya62@gmail.com9920605610+91992060561044732YFinancial Planning, Mutual Funds, NISM certified
#
#
# Rekha Nitin Shah is a AMFI registered distributor.  Rekha Nitin Shah's office is located at FLAT NO 4, 2nd FlOORCHANDANGIRI BUILDING TILAK ROADOPP ASHA PAREKH HOSPITAL SANTACRUZ WESTMUMBAI.  They are licensed to distribute mutual funds under PAN number AONPS5949B and they are KYD (Know Your Distributor) Complaint.  All transactions to Rekha Nitin Shah are tagged in ARN-127424
#
#
# ...

# %%
name=[]
for i in l:
    if "is" in i and "at" in i and "They" in i and "PAN" in i:
        name.append(i[:i.index(" is ")])

# %%
len(name)
# Out:
# 64063

# %%
name
# Out:
# ['Rekha Nitin Shah',
#  'Asian Markets Securities Pvt. Ltd',
#  'Biswajit Mondal',
#  'Alka Rajendra Khandelwal',
#  'S AND D FINANCIAL SERVICES',
#  'Kamlesh Ramniklal Bhayani',
#  'Thomas K George',
#  'Sunil Patodia',
#  'Bhinde Harshad',
#  'AATALGO',
#  'Vriksha Investments Private Limited',
#  'Devendra Kishorkant Trivedi',
#  'Prashant Sonu Salvi',
#  'Jupalli Satish',
#  'Chetana Yashodhan Bharade',
#  'Ashok Dinkar Deshpande',
#  'Pritam Singh',
#  'DHYEY ASSET ADVISORS LLP',
#  'MONEY PLANT WEALTH SOLUTIONS',
#  'Vijay Bhogilai Doshi',
#  'Mamta Kumari',
#  'R Gunasekaran',
#  'GLOBUS FINANCIAL SERVICES',
#  'Ram Thaker',
#  'Chandra Kanti Srivastava',
#  'Ketan Baherawala',
#  'Ajay Navinchandra Doshi',
#  'Pramila Rastogi',
#  'Shashi Bhushan',
#  'Hardikkumar Ganpatbhai Prajapati',
#  'Siddamallappa G N',
#  'Deepak Kantilal Shah',
#  'Prasanta Majumdar',
#  'Meeta Upadhyay',
#  'Vishesh Chawla',
#  'Indap T M',
#  'Priynka Rajendra Bhamare',
# ...

# %%
Location=[]
for i in l:
    if "is" in i and "at" in i and "They" in i and "PAN" in i:
        Location.append(i[i.index(" at ")+4:i.index(" They ")])

# %%
len(Location)
# Out:
# 64063

# %%
Location
# Out:
# ['FLAT NO 4, 2nd FlOORCHANDANGIRI BUILDING TILAK ROADOPP ASHA PAREKH HOSPITAL SANTACRUZ WESTMUMBAI. ',
#  'Athena House Row H No 2Rajini Gandha GokuldhamGoregaon EastMUMBAI. ',
#  'Vill-ShillaP.O-RamgopalpurDist- Purba BarddhamanBurdwan. ',
#  'Dhar RoadManawarManawar. ',
#  '13,VARDHMAN NAGAR SOCIETYB/S.CENTRAL BANK OF INDIAVIJAY CROSS ROAD,NAVRANGPURAAHMEDABAD. ',
#  '73/15-madhuram ResidencySherawali Galli Navagam GhedR.S.PuramJamnagar. ',
#  'Plot No 40/41 New No 2V M K NagarVinayagapuramChennai. ',
#  'AvaniOxford,Phase-2,Block-5,Flat-14h,136JessoreRoad BangurAvenueKolkataNorth 24 Parganas. ',
#  '13,marutiplotsanskarnagar,BhujCitybhuj,BhujKachchh. ',
#  '1212/2B Shivaji NagarFC RoadPune. ',
#  'C/o.Morarji Chemicals Pvt Ltd.317/321,Prospect Chamber,512,5th Floor,Opp.Thomas Cook,D.N.Road,Fort.MUMBAI. ',
#  '13/04 Nehru VasahatNr. Gujarat SocietyOpp : Bavaliya Hanuman Temple,Mahuva. ',
#  '1 Siddharth Nagar S M Road NearPoornima Bldg Mulund WestMumbai. ',
# ...

# %%
Pan=[]
for i in l:
    if "is" in i and "at" in i and "They" in i and "PAN" in i:
        Pan.append(i[i.index("PAN")+10:i.index("PAN")+21])

# %%
len(Pan)
# Out:
# 64063

# %%
Pan
# Out:
# [' AONPS5949B',
#  ' AAACA9493L',
#  ' AHJPM8429P',
#  ' ADQPK3167M',
#  ' ADHFS9290G',
#  ' AHEPB5247P',
#  ' ACDPT1031D',
#  ' AESPP1957M',
#  ' AJZPB8465E',
#  ' ABDFA8336K',
#  ' AAACV1492L',
#  ' AAXPT6277D',
#  ' BGOPS0434B',
#  ' AGPPJ4420J',
#  ' AMNPB2409B',
#  ' ACHPD7733Q',
#  ' BJLPS5301K',
#  ' AAKFD7265L',
#  ' AMBPG8102G',
#  ' AGXPD4100H',
#  ' DNEPK8342H',
#  ' AFCPG2017G',
#  ' AAAPI2549C',
#  ' ALQPT1385C',
#  ' CRJPS3375Q',
#  ' AKSPB3681L',
#  ' AEPPD9747N',
#  ' ABTPR4411J',
#  ' ACXPB9806G',
#  ' CHHPP1355B',
#  ' AEDPS9305P',
#  ' AAGPS7077R',
#  ' ALQPM1682H',
#  ' ACHPU7288H',
#  ' ARXPC3376P',
#  ' AAKPI0939G',
#  ' CSSPB7740Q',
#  ' AABCC1632J',
#  ' AHDPV8459N',
#  ' AFUPA8674B',
#  ' AASPT9554C',
#  ' AEHPA2055E',
#  ' APWPG5249N',
#  ' ACIPC5824A',
#  ' AAKPW1304P',
#  ' ABHPY6827D',
#  ' CBNPD7592Q',
#  ' AGSPG0433B',
#  ' AAEPS5811P',
#  ' ABWPD5500B',
#  ' AQTPM3491J',
#  ' ANVPB4236B',
#  ' AITPD6414E',
#  ' AFGPM5461C',
#  ' AHLPP6906G',
# ...

# %%
df=pd.DataFrame({"NAME":name,"LOCATION":Location,'PAN':Pan})

# %%
df.to_csv("data_clean_1.csv")

# %%
for i in l[:20:2]:
    print(i)
    print()
    print()
# Out:
# NR Shreyas CrossingAmbawadiAhmedabad380006GUINDIABDEPS4292NBDEPS4292NGujaratjapanshah22@gmail.com25466694+91989894929244854YFinancial Planning, Mutual Funds, NISM certified
#
#
# Rekha Nitin Shah is a AMFI registered distributor.  Rekha Nitin Shah's office is located at FLAT NO 4, 2nd FlOORCHANDANGIRI BUILDING TILAK ROADOPP ASHA PAREKH HOSPITAL SANTACRUZ WESTMUMBAI.  They are licensed to distribute mutual funds under PAN number AONPS5949B and they are KYD (Know Your Distributor) Complaint.  All transactions to Rekha Nitin Shah are tagged in ARN-127424
#
#
# Biswajit Mondal is a AMFI registered distributor.  Biswajit Mondal's office is located at Vill-ShillaP.O-RamgopalpurDist- Purba BarddhamanBurdwan.  They are licensed to distribute mutual funds under PAN number AHJPM8429P and they are KYD (Know Your Distributor) Complaint.  All transactions to Biswajit Mondal are tagged in ARN-12388
#
#
# ...

# %%
df
# Out:
#                                     NAME  \
# 0                       Rekha Nitin Shah
# 1      Asian Markets Securities Pvt. Ltd
# 2                        Biswajit Mondal
# 3               Alka Rajendra Khandelwal
# 4             S AND D FINANCIAL SERVICES
# ...                                  ...
# 64058                   <p>Jadawati Devi
# 64059                Arvind Kumar Sharma
# 64060                       Sachin Kumar
# 64061                Uday Vir Singh Rana
# 64062       INGENIOUS FINANCIAL ADVISORS
#
#                                                 LOCATION          PAN
# 0      FLAT NO 4, 2nd FlOORCHANDANGIRI BUILDING TILAK...   AONPS5949B
# 1      Athena House Row H No 2Rajini Gandha Gokuldham...   AAACA9493L
# 2      Vill-ShillaP.O-RamgopalpurDist- Purba Barddham...   AHJPM8429P
# 3                              Dhar RoadManawarManawar.    ADQPK3167M
# 4      13,VARDHMAN NAGAR SOCIETYB/S.CENTRAL BANK OF I...   ADHFS9290G
# ...

# %%
f=[]
name=[]
for i in data["_source"]:
    if "about" in i.keys():
        if "@" in i["about"] and "India" in i["about"] and (".com" in i['about'] or ".in" in i['about'] or  ".org" in i['about'] or ".net" in i['about'] or ".co.uk" in i['about']):
            f.append(i["about"])
            name.append(i['name'])

# %%
len(f)
# Out:
# 42803

# %%
len(name)
# Out:
# 42803

# %%
name
# Out:
# ['Hemant Kantilal Pandya',
#  'Shaikh Shaheen Musa',
#  'Mohammed Aslam',
#  'Nital Sanjay Mhatre',
#  'Bhikhu Parsottamdas Patel',
#  'Dahyalal S Soni',
#  'L Naga Rajsekhar',
#  'Amar Babu Suchdeo',
#  'Madhusudhan S Goudar',
#  'Shivam Lamba',
#  'Asha Basal',
#  'Sheth Wealth Management',
#  'Venkata Gopal Sadhu',
#  'Jayachitra S',
#  'Akil Mohammed Sufi',
#  'Girish Vinayak Borhade',
#  'Rakesh Kumar Raushan',
#  'Maheshkumar K Bhagat',
#  'Preeti Ladha',
#  'K M Niranjan',
#  'Ramakrishna',
#  'Rajesh Kumar Singh',
#  'Akata B Rajpurohit',
#  'Sudhir Ganesh Athalye',
#  'Dron Nehal Amit',
#  'FinCare',
#  'Shri Nath Sahai',
#  'Nayan Bharatbhai Pandya',
#  'SHAH INVESTMENTS',
#  'Acumen Consulting',
#  'Shraddha Gupta',
#  'Geetesh Kumar Kashyap',
#  'Abhay Dubey',
#  'Aneesh S',
#  'Jagdish Prasad Rathi',
#  'Ashwin Natvarlal Mehta',
#  'Prasannakumar G N',
#  'Shashank Goswami',
#  'Kiran Kumar Nl',
#  'K R Prabakar',
#  'Prakash Paul',
#  'Aniket Prakash Kulkarni',
# ...

# %%
f
# Out:
# ['Kantilal ComplexMohoneKalyan421102MAIndiaABAPP3781EABAPP3781EMaharashtrahemant.pandya62@gmail.com9920605610+91992060561044732YFinancial Planning, Mutual Funds, NISM certified',
#  'Mohammadwadi RoadHadapsarPune411028MAIndiaBUSPS8328EBUSPS8328EMaharashtrashaheen_shaikh88@yahoo.com+91956179536442761YFinancial Planning, Mutual Funds, NISM certified',
#  'Opp Old Bowenpally Check Post,Old Bowenpally,Hyderabad500011TLIndiaAFVPA4299PAFVPA4299PTelanganaaslam@deccanfinancials.com9652551777+91817977062643079YFinancial Planning, Mutual Funds, NISM certified',
#  'Near Pranay Nagar VaziraBorivali (W)Mumbai400091MAIndiaAHRPM9286CAHRPM9286CMaharashtrasannita72@rediffmail.com28994033+91981975787444750YFinancial Planning, Mutual Funds, NISM certified',
#  'Tal-JalalporeNavsariNavsari396472GUIndiaAPAPP2985AAPAPP2985AGujaratbhikhuppatel@yahoo.com9879890405+91987989040544635YFinancial Planning, Mutual Funds, NISM certified',
# ...

# %%
import matplotlib.pyplot as plt
x=['a','c','b','d']
y=[10,20,30,25]
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=['a','c','b','d']
y=[10,20,30,25]
plt.bar(x,y,color='r',width=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
x=['a','c','b','d']
y=[10,20,30,25]
plt.barh(x,y,color='r',height=0.5)
plt.show()

# %%
x=['a','c','b','d']
y=[10,20,30,25]
plt.pie(y,labels=x)
plt.show()

# %%
import pandas as pd
tech={
'Courses':["Spark","PySpark","Hadoop","Python","pandas"],
    'Fee' :[20000,25000,26000,22000,24000],
    'Duration':['30day','40days','35days','40days','60days'],
    'Discount':[1000,2300,1200,2500,2000]
  }
r=['r1','r2','r3','r4','r5']
df=pd.DataFrame(tech,index=r)

# %%
df
# Out:
#     Courses    Fee Duration  Discount
# r1    Spark  20000    30day      1000
# r2  PySpark  25000   40days      2300
# r3   Hadoop  26000   35days      1200
# r4   Python  22000   40days      2500
# r5   pandas  24000   60days      2000

# %%
plt.bar(df['Courses'],df['Fee'],color='brown')
plt.title("Comparison")
plt.xlabel('course')
plt.ylabel('fees')
plt.show()

# %%
plt.pie(df['Fee'],labels=df['Courses'],autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1eca670b170>,
# ...
#  [Text(0.9451582194875106, 0.5627396735038315, 'Spark'),
#   Text(-0.1910130348765979, 1.0832885213585675, 'PySpark'),
#   Text(-1.0996034818677685, 0.029532738855044868, 'Hadoop'),
#   Text(-0.33429560498432986, -1.0479725418579253, 'Python'),
#   Text(0.8793870960615077, -0.6608164157165807, 'pandas')],
#  [Text(0.5155408469931876, 0.30694891282027165, '17.1%'),
#   Text(-0.10418892811450793, 0.5908846480137641, '21.4%'),
#   Text(-0.5997837173824191, 0.01610876664820629, '22.2%'),
#   Text(-0.1823430572641799, -0.5716213864679592, '18.8%'),
#   Text(0.47966568876082233, -0.3604453176635894, '20.5%')])

# %%
plt.plot(df['Courses'],df['Discount'])
plt.show()

# %%
plt.plot(df['Courses'],df['Fee'])

# %%
plt.figure(figsize=(10, 6)) 

plt.subplot(2, 2, 1)  
plt.bar(df['Courses'], df['Fee'], color='brown')
plt.title('Bar Chart')
plt.xlabel('Courses')
plt.ylabel('Fees')

plt.subplot(2, 2, 2)
plt.plot(df['Courses'], df['Fee'], color='blue', marker='o')
plt.title('Line Chart')
plt.xlabel('Courses')
plt.ylabel('Fees')


plt.subplot(2, 2, 3)
plt.scatter(df['Courses'], df['Fee'], color='green')
plt.title('Scatter Plot')
plt.xlabel('Courses')
plt.ylabel('Fees')

plt.subplot(2, 2, 4)
plt.barh(df['Courses'], df['Fee'], color='purple')
plt.title('Horizontal Bar Chart')
plt.xlabel('Fees')
plt.ylabel('Courses')


plt.tight_layout() 

plt.show()

# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\kushv\\Downloads\\IMDB-Movie-Data.csv")

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6)) 
x=data["Title"].head()
y=data["Votes"].head()
plt.bar(x,y)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6)) 
x=data["Title"].head()
y=data["Votes"].head()
data=data.sort_values("Votes",ascending=True)
data
plt.bar(x,y)
plt.tight_layout()
plt.show()

# %%
b=data["Genre"].value_counts()

# %%
b
# Out:
# Genre
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Comedy,Drama,Musical        1
# Comedy,Horror,Sci-Fi        1
# Action,Drama,Horror         1
# Drama,Thriller,War          1
# Drama,Western               1
# Name: count, Length: 207, dtype: int64

# %%
a=data["Title"].value_counts(ascending=True)
a
# Out:
# Title
# Paint It Black          1
# Transcendence           1
# Contagion               1
# Rambo                   1
# The Road                1
#                        ..
# Sex and the City 2      1
# Fool's Gold             1
# Dragonball Evolution    1
# The Dark Knight         1
# The Host                2
# Name: count, Length: 999, dtype: int64

# %%
#to get number of movies per year
c=data["Year"].value_counts(ascending=False)
c
plt.bar(c.index,c.values)
plt.show()

# %%
c=data["Year"].value_counts(ascending=False)
c
plt.bar(c.values,c.index)
plt.show()

# %%
c=data["Year"].value_counts(ascending=False)
c
c.plot(kind="bar")
plt.show()

# %%
d=data['Genre'].str.split(",").explode()
d
# Out:
# 478        Drama
# 293        Drama
# 393       Comedy
# 393      Romance
# 337        Drama
#          ...
# 80     Adventure
# 80        Sci-Fi
# 54        Action
# 54         Crime
# 54         Drama
# Name: Genre, Length: 2555, dtype: object

# %%
d=data['Genre'].str.split(",").explode().value_counts()
d
d.plot(kind="bar")
plt.show()

# %%
data['Genre'].str.split(",",expand=True)
# Out:
#              0          1       2
# 478      Drama       None    None
# 293      Drama       None    None
# 393     Comedy    Romance    None
# 337      Drama      Sport    None
# 416      Drama       None    None
# ..         ...        ...     ...
# 76      Action     Sci-Fi    None
# 36   Adventure      Drama  Sci-Fi
# 124     Action   Thriller    None
# 80      Action  Adventure  Sci-Fi
# 54      Action      Crime   Drama
#
# [1000 rows x 3 columns]

# %%
data['Genre'].str.split(",",expand=True).stack()
# Out:
# 478  0        Drama
# 293  0        Drama
# 393  0       Comedy
#      1      Romance
# 337  0        Drama
#             ...
# 80   1    Adventure
#      2       Sci-Fi
# 54   0       Action
#      1        Crime
#      2        Drama
# Length: 2555, dtype: object

# %%
data['Genre'].str.split(",",expand=True).value_counts()
# Out:
# 0          1          2
# Action     Adventure  Sci-Fi      50
# Comedy     Drama      Romance     35
# Animation  Adventure  Comedy      27
# Action     Adventure  Fantasy     27
# Crime      Drama      Thriller    24
#                                   ..
# Comedy     Family     Musical      1
#                       Fantasy      1
#            Drama      Thriller     1
# Action     Thriller   War          1
# Romance    Sci-Fi     Thriller     1
# Name: count, Length: 156, dtype: int64

# %%
e=data['Genre'].str.split(",",expand=True).value_counts()
e.plot(kind="bar")
plt.show()

# %%
data
# Out:
#      Rank                     Title                    Genre  \
# 478   479            Paint It Black                    Drama
# 293   294             The Exception                    Drama
# 393   394             Whisky Galore           Comedy,Romance
# 337   338                 Tracktown              Drama,Sport
# 416   417  The Headhunter's Calling                    Drama
# ..    ...                       ...                      ...
# 76     77              The Avengers            Action,Sci-Fi
# 36     37              Interstellar   Adventure,Drama,Sci-Fi
# 124   125     The Dark Knight Rises          Action,Thriller
# 80     81                 Inception  Action,Adventure,Sci-Fi
# 54     55           The Dark Knight       Action,Crime,Drama
#
#                                            Description           Director  \
# 478  A young woman attempts to deal with the death ...      Amber Tamblyn
# 293  A German soldier tries to determine if the Dut...      David Leveaux
# ...

# %%
e='Action Movie Name'
e.split()
# Out:
# ['Action', 'Movie', 'Name']

# %%
data={
    'A':[101,102,102,103,104,105,105],
    'B':['a','b','b','c','d','e','e']
}
th=pd.DataFrame(data)
th
# Out:
#      A  B
# 0  101  a
# 1  102  b
# 2  102  b
# 3  103  c
# 4  104  d
# 5  105  e
# 6  105  e

# %%
th1=th.duplicated()  # to check duplicates
th1
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
th2=th.drop_duplicates() # to remove duplicate and form in table
th2
# Out:
#      A  B
# 0  101  a
# 1  102  b
# 3  103  c
# 4  104  d
# 5  105  e

# %%
df={
    'A':[1,2,None,4],
    'B':[None,2,3,4],
    'C':['a',None,'c','d']
}
ph=pd.DataFrame(df)
ph
# Out:
#      A    B     C
# 0  1.0  NaN     a
# 1  2.0  2.0  None
# 2  NaN  3.0     c
# 3  4.0  4.0     d

# %%
ph.isnull()  # jaha null hoga vha true
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False   True
# 2   True  False  False
# 3  False  False  False

# %%
ph.isna() # same as  isnull
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False   True
# 2   True  False  False
# 3  False  False  False

# %%
ph.notna()
# Out:
#        A      B      C
# 0   True  False   True
# 1   True   True  False
# 2  False   True   True
# 3   True   True   True

# %%
ph.dropna()
# Out:
#      A    B  C
# 3  4.0  4.0  d

# %%
ph.drop_notna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19676\911199993.py in ?()
# ----> 1 ph.drop_notna()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_notna'

# %%
ph.dropna(subset=['A','B'])
# Out:
#      A    B     C
# 1  2.0  2.0  None
# 3  4.0  4.0     d

# %%
ph.fillna(method='ffill')
# Out:
# C:\Users\kushv\AppData\Local\Temp\ipykernel_19676\1129926028.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ph.fillna(method='ffill')
#      A    B  C
# 0  1.0  NaN  a
# 1  2.0  2.0  a
# 2  2.0  3.0  c
# 3  4.0  4.0  d

# %%
ph.fillna(method='bfill')
# Out:
# C:\Users\kushv\AppData\Local\Temp\ipykernel_19676\3621722757.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ph.fillna(method='bfill')
#      A    B  C
# 0  1.0  2.0  a
# 1  2.0  2.0  c
# 2  4.0  3.0  c
# 3  4.0  4.0  d

# %%
ph['A'].fillna(ph['A'].mean())
# Out:
# 0    1.000000
# 1    2.000000
# 2    2.333333
# 3    4.000000
# Name: A, dtype: float64
